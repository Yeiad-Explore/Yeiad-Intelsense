# %% [markdown]
# # **Youtube Video to Audio**
# This Google Colab file automates the process of downloading YouTube videos as MP3 files and uploading them to an Amazon S3 bucket. The workflow involves the following steps:
#
# *   **Extract Video ID**: The notebook extracts the video ID from a given YouTube URL.
# *   **Download Video**: It downloads the audio from the YouTube video in the best available format.
#
# *   **Convert to MP3**: The downloaded audio is then converted to MP3 format.
#
# *   **Check for Duplicates**: Before downloading, it checks if the video already exists in the S3 bucket to avoid duplicates.
# *   **Upload to S3**: The converted MP3 files are then uploaded to an Amazon S3 bucket.
#
# <br>
#
# **Instructions to Run in Google Colab:**
#
#
#
#
# *   **Set Bucket Names:** Update the variables BUCKET_NAME and CHUNKS_BUCKET_NAME in the notebook with your Amazon S3 bucket names where the MP3 files will be uploaded.
# *   **Provide YouTube URLs:**In the notebook, input the list of YouTube URLs you want to download and convert to MP3 format.
#
#
#
# *   **Run the Notebook:**Execute each cell one by one by clicking Run or pressing Shift + Enter to download the YouTube videos, convert them to MP3 format, and upload them to your S3 bucket.
#
# *  **Check for Duplicate Files:** The script will automatically check if the video has already been uploaded to the S3 bucket and skip downloading if a duplicate is found.

# %% [markdown]
# # Run The followig cells

# %%
# !pip install git+https://github.com/yt-dlp/yt-dlp.git -q
# !pip install boto3 -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for yt-dlp (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 8.4 MB/s eta 0:00:00

# %%
import json
import os
from yt_dlp import YoutubeDL
import boto3

# %%
from google.colab import userdata

AWS_ACCESS_KEY = userdata.get("aws_access_key")
AWS_SECRET_KEY = userdata.get("aws_secret_key")

s3 = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY, aws_secret_access_key=AWS_SECRET_KEY)

# %%
BUCKET_NAME = 'yt-dl-mp3'
CHUNKS_BUCKET_NAME = 'yt-chunk-mp3'

def check_s3_for_file(file_key, bucket_name):
    """Checks if a file with the given key exists in the specified S3 bucket."""
    try:
        response = s3.list_objects_v2(Bucket=bucket_name, Prefix=file_key)
        for obj in response.get('Contents', []):
            if obj['Key'] == file_key:
                print(f"File {file_key} already exists in S3 (bucket: {bucket_name}).")
                return True
    except Exception as e:
        print(f"Error checking S3 for file {file_key} in bucket {bucket_name}: {e}")
    return False


def uploader_to_s3(file_path):
    """Uploads a file to the specified S3 bucket if it doesn't exist in either bucket."""
    try:
        s3_key = os.path.relpath(file_path, start='downloads')
        file_id = os.path.splitext(os.path.basename(s3_key))[0]  # Extract file ID (without extension)

        s3.upload_file(file_path, BUCKET_NAME, s3_key)
        print(f"Uploaded to S3: s3://{BUCKET_NAME}/{s3_key}")

    except Exception as e:
        print(f"Failed to upload {file_path} to S3: {e}")

def on_complete(d):
    """Callback when a file download is complete."""
    if d['status'] == 'finished' and d['info_dict'].get('filepath') is not None:
        filename = d['info_dict']['filepath']
        if filename.endswith(".mp3"):
            print(f"Saved: {filename}")
            uploader_to_s3(filename)  # Upload the file to S3 if not a duplicate
            os.remove(filename)
    elif d['status'] == 'error':
        print("Download failed")
        print(d['error'])

ydl_opts = {
    'abort_on_unavailable_fragments': True,
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '128',
    }],
    'postprocessor_args': [
        '-ar', '16000',
        '-ac', '1'
    ],
    'prefer_ffmpeg': True,
    'keepvideo': False,
    'outtmpl': 'downloads/%(id)s.%(ext)s',
    'postprocessor_hooks': [on_complete]
}

urls = [
    "https://www.youtube.com/@kollol"
]

# %%
def list_videos(url):
    ydl_opts = {
        'quiet': True,
        'extract_flat': True,  # Extract only video metadata, no download
        'force_generic_extractor': False,
    }
    with YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=False)
    return info

# %%
actual_urls = []

with YoutubeDL(ydl_opts) as ydl:
    for url in urls:
        print(f"Received URL: {url}")

        if not url.startswith('https://www.youtube.com/playlist?list=') and not url.startswith('https://www.youtube.com/@') and not url.startswith('https://www.youtube.com/watch?v='):
            print(f"Skipping invalid URL: {url}")
            continue

        if url.startswith('https://www.youtube.com/@') and not url.endswith('/videos'):
            url = url + '/videos'

        videos = list_videos(url)
        print("Video metadata downloaded")
        if videos.get('entries') is not None:
            print(f"Found {len(videos['entries'])} videos in the URL.")
            for video in videos['entries']:
                video_url = video['url']
                actual_urls.append(video_url)
        else:
            actual_urls.append(url)
# Out:
# Received URL: https://www.youtube.com/@kollol
# Video metadata downloaded
# Found 1005 videos in the URL.

# %%
len(actual_urls)
# Out:
# 1005

# %%
from concurrent.futures import ThreadPoolExecutor
import re

def extract_video_id(url):
    """Extracts the video ID from a YouTube URL."""
    match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11})", url)
    return match.group(1) if match else None

def check_for_duplicates(video_id):
    """Checks for duplicates in both S3 buckets."""
    mp3_key = f"{video_id}.mp3"
    chunks_prefix = f"chunks/{video_id}"

    return check_s3_for_file(mp3_key, BUCKET_NAME) or check_s3_for_file(chunks_prefix, CHUNKS_BUCKET_NAME)

def download_video(url):
    """Downloads the video if it doesn't exist in S3."""
    video_id = extract_video_id(url)
    if not video_id:
        print(f"Invalid URL: {url}")
        return

    print(f"Checking for duplicates: {video_id}")
    if check_for_duplicates(video_id):
        print(f"Skipping download: {video_id} already exists in S3.")
        return

    ydl_opts = {
        'abort_on_unavailable_fragments': True,
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '128',
        }],
        'postprocessor_args': [
            '-ar', '16000',
            '-ac', '1'
        ],
        'prefer_ffmpeg': True,
        'keepvideo': False,
        'outtmpl': f'downloads/{video_id}.%(ext)s',
        'postprocessor_hooks': [on_complete]
    }

    with YoutubeDL(ydl_opts) as ydl:
        try:
            print(f"Downloading: {url}")
            ydl.download([url])
        except Exception as e:
            print(f"Error downloading {url}: {e}")

# Run downloads in parallel
with ThreadPoolExecutor(max_workers=4) as executor:
    futures = [executor.submit(download_video, url) for url in actual_urls]

# Wait for all downloads to complete
for future in futures:
    future.result()
# Out:
# Streaming output truncated to the last 5000 lines.
# [youtube] 2rQeONhd5SE: Downloading webpage
# [youtube] 2rQeONhd5SE: Downloading ios player API JSON
# [youtube] 2rQeONhd5SE: Downloading mweb player API JSON
# [youtube] 2rQeONhd5SE: Downloading m3u8 information
# [info] 2rQeONhd5SE: Downloading 1 format(s): 251
# [download] Destination: downloads/2rQeONhd5SE.webm
# [download]  39.4% of   35.24MiB at    9.64MiB/s ETA 00:02Deleting original file downloads/bFVy8m7iDQw.webm (pass -k to keep)
# Saved: downloads/bFVy8m7iDQw.mp3
# [download] 100% of   35.24MiB in 00:00:03 at 9.34MiB/s
# [ExtractAudio] Destination: downloads/2rQeONhd5SE.mp3
# Uploaded to S3: s3://yt-dl-mp3/bFVy8m7iDQw.mp3
# Checking for duplicates: 5rLoe0CFn3c
# Downloading: https://www.youtube.com/watch?v=5rLoe0CFn3c
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5rLoe0CFn3c
# [youtube] 5rLoe0CFn3c: Downloading webpage
# [youtube] 5rLoe0CFn3c: Downloading ios player API JSON
# [youtube] 5rLoe0CFn3c: Downloading mweb player API JSON
# [youtube] 5rLoe0CFn3c: Downloading m3u8 information
# [info] 5rLoe0CFn3c: Downloading 1 format(s): 251
# [download] Destination: downloads/5rLoe0CFn3c.webm
# [download] 100% of   46.10MiB in 00:00:03 at 12.73MiB/s
# [ExtractAudio] Destination: downloads/5rLoe0CFn3c.mp3
# Deleting original file downloads/vySdO7epWio.webm (pass -k to keep)
# Saved: downloads/vySdO7epWio.mp3
# Uploaded to S3: s3://yt-dl-mp3/vySdO7epWio.mp3
# Checking for duplicates: R7j6jRkXLJI
# Downloading: https://www.youtube.com/watch?v=R7j6jRkXLJI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=R7j6jRkXLJI
# [youtube] R7j6jRkXLJI: Downloading webpage
# [youtube] R7j6jRkXLJI: Downloading ios player API JSON
# [youtube] R7j6jRkXLJI: Downloading mweb player API JSON
# [youtube] R7j6jRkXLJI: Downloading m3u8 information
# [info] R7j6jRkXLJI: Downloading 1 format(s): 251
# [download] Destination: downloads/R7j6jRkXLJI.webm
# [download] 100% of   42.83MiB in 00:00:07 at 5.92MiB/s
# [ExtractAudio] Destination: downloads/R7j6jRkXLJI.mp3
# Deleting original file downloads/RvyFU5IbjEY.webm (pass -k to keep)
# Saved: downloads/RvyFU5IbjEY.mp3
# Uploaded to S3: s3://yt-dl-mp3/RvyFU5IbjEY.mp3
# Checking for duplicates: i9tduVg-5Uw
# Downloading: https://www.youtube.com/watch?v=i9tduVg-5Uw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=i9tduVg-5Uw
# [youtube] i9tduVg-5Uw: Downloading webpage
# [youtube] i9tduVg-5Uw: Downloading ios player API JSON
# [youtube] i9tduVg-5Uw: Downloading mweb player API JSON
# [youtube] i9tduVg-5Uw: Downloading m3u8 information
# [info] i9tduVg-5Uw: Downloading 1 format(s): 251
# [download] Destination: downloads/i9tduVg-5Uw.webm
# [download]  43.0% of   41.68MiB at   12.31MiB/s ETA 00:01Deleting original file downloads/2rQeONhd5SE.webm (pass -k to keep)
# Saved: downloads/2rQeONhd5SE.mp3
# [download] 100% of   41.68MiB in 00:00:04 at 10.17MiB/s
# [ExtractAudio] Destination: downloads/i9tduVg-5Uw.mp3
# Uploaded to S3: s3://yt-dl-mp3/2rQeONhd5SE.mp3
# Checking for duplicates: 1GqQ2wLdVYo
# Downloading: https://www.youtube.com/watch?v=1GqQ2wLdVYo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1GqQ2wLdVYo
# [youtube] 1GqQ2wLdVYo: Downloading webpage
# [youtube] 1GqQ2wLdVYo: Downloading ios player API JSON
# [youtube] 1GqQ2wLdVYo: Downloading mweb player API JSON
# [youtube] 1GqQ2wLdVYo: Downloading m3u8 information
# [info] 1GqQ2wLdVYo: Downloading 1 format(s): 251
# [download] Destination: downloads/1GqQ2wLdVYo.webm
# [download] 100% of   44.24MiB in 00:00:06 at 6.41MiB/s
# [ExtractAudio] Destination: downloads/1GqQ2wLdVYo.mp3
# Deleting original file downloads/5rLoe0CFn3c.webm (pass -k to keep)
# Saved: downloads/5rLoe0CFn3c.mp3
# Uploaded to S3: s3://yt-dl-mp3/5rLoe0CFn3c.mp3
# Checking for duplicates: rDGEPFXMN1s
# Downloading: https://www.youtube.com/watch?v=rDGEPFXMN1s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rDGEPFXMN1s
# [youtube] rDGEPFXMN1s: Downloading webpage
# [youtube] rDGEPFXMN1s: Downloading ios player API JSON
# [youtube] rDGEPFXMN1s: Downloading mweb player API JSON
# [youtube] rDGEPFXMN1s: Downloading m3u8 information
# [info] rDGEPFXMN1s: Downloading 1 format(s): 251
# [download] Destination: downloads/rDGEPFXMN1s.webm
# [download] 100% of   40.33MiB in 00:00:07 at 5.31MiB/s
# [ExtractAudio] Destination: downloads/rDGEPFXMN1s.mp3
# Deleting original file downloads/R7j6jRkXLJI.webm (pass -k to keep)
# Saved: downloads/R7j6jRkXLJI.mp3
# Uploaded to S3: s3://yt-dl-mp3/R7j6jRkXLJI.mp3
# Checking for duplicates: kGKuCWsrc8Q
# Downloading: https://www.youtube.com/watch?v=kGKuCWsrc8Q
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kGKuCWsrc8Q
# [youtube] kGKuCWsrc8Q: Downloading webpage
# [youtube] kGKuCWsrc8Q: Downloading ios player API JSON
# [youtube] kGKuCWsrc8Q: Downloading mweb player API JSON
# [youtube] kGKuCWsrc8Q: Downloading m3u8 information
# [info] kGKuCWsrc8Q: Downloading 1 format(s): 251
# [download] Destination: downloads/kGKuCWsrc8Q.webm
# [download] 100% of   40.40MiB in 00:00:07 at 5.65MiB/s
# [ExtractAudio] Destination: downloads/kGKuCWsrc8Q.mp3
# Deleting original file downloads/i9tduVg-5Uw.webm (pass -k to keep)
# Saved: downloads/i9tduVg-5Uw.mp3
# Uploaded to S3: s3://yt-dl-mp3/i9tduVg-5Uw.mp3
# Checking for duplicates: zJhDD7FOhN0
# Downloading: https://www.youtube.com/watch?v=zJhDD7FOhN0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zJhDD7FOhN0
# [youtube] zJhDD7FOhN0: Downloading webpage
# [youtube] zJhDD7FOhN0: Downloading ios player API JSON
# [youtube] zJhDD7FOhN0: Downloading mweb player API JSON
# [youtube] zJhDD7FOhN0: Downloading m3u8 information
# [info] zJhDD7FOhN0: Downloading 1 format(s): 251
# [download] Destination: downloads/zJhDD7FOhN0.webm
# [download] 100% of   40.30MiB in 00:00:07 at 5.51MiB/s
# Deleting original file downloads/1GqQ2wLdVYo.webm (pass -k to keep)
# Saved: downloads/1GqQ2wLdVYo.mp3
# [ExtractAudio] Destination: downloads/zJhDD7FOhN0.mp3
# Uploaded to S3: s3://yt-dl-mp3/1GqQ2wLdVYo.mp3
# Checking for duplicates: 6fCQnkny03Y
# Downloading: https://www.youtube.com/watch?v=6fCQnkny03Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6fCQnkny03Y
# [youtube] 6fCQnkny03Y: Downloading webpage
# [youtube] 6fCQnkny03Y: Downloading ios player API JSON
# [youtube] 6fCQnkny03Y: Downloading mweb player API JSON
# [youtube] 6fCQnkny03Y: Downloading m3u8 information
# [info] 6fCQnkny03Y: Downloading 1 format(s): 251
# [download] Destination: downloads/6fCQnkny03Y.webm
# [download] 100% of   46.47MiB in 00:00:08 at 5.43MiB/s
# [ExtractAudio] Destination: downloads/6fCQnkny03Y.mp3
# Deleting original file downloads/rDGEPFXMN1s.webm (pass -k to keep)
# Saved: downloads/rDGEPFXMN1s.mp3
# Uploaded to S3: s3://yt-dl-mp3/rDGEPFXMN1s.mp3
# Checking for duplicates: u_y3fRiejUk
# Downloading: https://www.youtube.com/watch?v=u_y3fRiejUk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=u_y3fRiejUk
# [youtube] u_y3fRiejUk: Downloading webpage
# [youtube] u_y3fRiejUk: Downloading ios player API JSON
# [youtube] u_y3fRiejUk: Downloading mweb player API JSON
# [youtube] u_y3fRiejUk: Downloading m3u8 information
# [info] u_y3fRiejUk: Downloading 1 format(s): 251
# [download] Destination: downloads/u_y3fRiejUk.webm
# [download]  86.3% of   45.29MiB at    3.30MiB/s ETA 00:01Deleting original file downloads/kGKuCWsrc8Q.webm (pass -k to keep)
# Saved: downloads/kGKuCWsrc8Q.mp3
# [download] 100% of   45.29MiB in 00:00:11 at 4.05MiB/s
# [ExtractAudio] Destination: downloads/u_y3fRiejUk.mp3
# Uploaded to S3: s3://yt-dl-mp3/kGKuCWsrc8Q.mp3
# Checking for duplicates: TypWSm73N7M
# Downloading: https://www.youtube.com/watch?v=TypWSm73N7M
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TypWSm73N7M
# [youtube] TypWSm73N7M: Downloading webpage
# [youtube] TypWSm73N7M: Downloading ios player API JSON
# [youtube] TypWSm73N7M: Downloading mweb player API JSON
# [youtube] TypWSm73N7M: Downloading m3u8 information
# [info] TypWSm73N7M: Downloading 1 format(s): 251
# [download] Destination: downloads/TypWSm73N7M.webm
# [download] 100% of   42.81MiB in 00:00:04 at 8.91MiB/s
# [ExtractAudio] Destination: downloads/TypWSm73N7M.mp3
# Deleting original file downloads/zJhDD7FOhN0.webm (pass -k to keep)
# Saved: downloads/zJhDD7FOhN0.mp3
# Uploaded to S3: s3://yt-dl-mp3/zJhDD7FOhN0.mp3
# Checking for duplicates: jqAdCXS6DlA
# Downloading: https://www.youtube.com/watch?v=jqAdCXS6DlA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jqAdCXS6DlA
# [youtube] jqAdCXS6DlA: Downloading webpage
# [youtube] jqAdCXS6DlA: Downloading ios player API JSON
# [youtube] jqAdCXS6DlA: Downloading mweb player API JSON
# [youtube] jqAdCXS6DlA: Downloading m3u8 information
# [info] jqAdCXS6DlA: Downloading 1 format(s): 251
# [download] Destination: downloads/jqAdCXS6DlA.webm
# [download] 100% of   40.50MiB in 00:00:06 at 5.92MiB/s
# [ExtractAudio] Destination: downloads/jqAdCXS6DlA.mp3
# Deleting original file downloads/6fCQnkny03Y.webm (pass -k to keep)
# Saved: downloads/6fCQnkny03Y.mp3
# Uploaded to S3: s3://yt-dl-mp3/6fCQnkny03Y.mp3
# Checking for duplicates: J78uldnzT3s
# Downloading: https://www.youtube.com/watch?v=J78uldnzT3s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=J78uldnzT3s
# [youtube] J78uldnzT3s: Downloading webpage
# [youtube] J78uldnzT3s: Downloading ios player API JSON
# [youtube] J78uldnzT3s: Downloading mweb player API JSON
# [youtube] J78uldnzT3s: Downloading m3u8 information
# [info] J78uldnzT3s: Downloading 1 format(s): 251
# [download] Destination: downloads/J78uldnzT3s.webm
# [download] 100% of   37.90MiB in 00:00:10 at 3.74MiB/s
# [ExtractAudio] Destination: downloads/J78uldnzT3s.mp3
# Deleting original file downloads/u_y3fRiejUk.webm (pass -k to keep)
# Saved: downloads/u_y3fRiejUk.mp3
# Uploaded to S3: s3://yt-dl-mp3/u_y3fRiejUk.mp3
# Checking for duplicates: Nh7PXH8olI8
# Downloading: https://www.youtube.com/watch?v=Nh7PXH8olI8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Nh7PXH8olI8
# [youtube] Nh7PXH8olI8: Downloading webpage
# [youtube] Nh7PXH8olI8: Downloading ios player API JSON
# [youtube] Nh7PXH8olI8: Downloading mweb player API JSON
# Deleting original file downloads/TypWSm73N7M.webm (pass -k to keep)
# Saved: downloads/TypWSm73N7M.mp3
# [youtube] Nh7PXH8olI8: Downloading m3u8 information
# [info] Nh7PXH8olI8: Downloading 1 format(s): 251
# [download] Destination: downloads/Nh7PXH8olI8.webm
# [download] 100% of   36.28MiB in 00:00:01 at 23.15MiB/s
# [ExtractAudio] Destination: downloads/Nh7PXH8olI8.mp3
# Uploaded to S3: s3://yt-dl-mp3/TypWSm73N7M.mp3
# Checking for duplicates: JlQhbkzhfq8
# Downloading: https://www.youtube.com/watch?v=JlQhbkzhfq8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JlQhbkzhfq8
# [youtube] JlQhbkzhfq8: Downloading webpage
# [youtube] JlQhbkzhfq8: Downloading ios player API JSON
# [youtube] JlQhbkzhfq8: Downloading mweb player API JSON
# [youtube] JlQhbkzhfq8: Downloading m3u8 information
# [info] JlQhbkzhfq8: Downloading 1 format(s): 251
# [download] Destination: downloads/JlQhbkzhfq8.webm
# [download] 100% of   39.89MiB in 00:00:03 at 12.81MiB/s
# [ExtractAudio] Destination: downloads/JlQhbkzhfq8.mp3
# Deleting original file downloads/jqAdCXS6DlA.webm (pass -k to keep)
# Saved: downloads/jqAdCXS6DlA.mp3
# Uploaded to S3: s3://yt-dl-mp3/jqAdCXS6DlA.mp3
# Checking for duplicates: jCuST_l5r-w
# Downloading: https://www.youtube.com/watch?v=jCuST_l5r-w
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jCuST_l5r-w
# [youtube] jCuST_l5r-w: Downloading webpage
# [youtube] jCuST_l5r-w: Downloading ios player API JSON
# [youtube] jCuST_l5r-w: Downloading mweb player API JSON
# [youtube] jCuST_l5r-w: Downloading m3u8 information
# [info] jCuST_l5r-w: Downloading 1 format(s): 251
# [download] Destination: downloads/jCuST_l5r-w.webm
# [download] 100% of   43.32MiB in 00:00:07 at 6.04MiB/s
# [ExtractAudio] Destination: downloads/jCuST_l5r-w.mp3
# Deleting original file downloads/J78uldnzT3s.webm (pass -k to keep)
# Saved: downloads/J78uldnzT3s.mp3
# Uploaded to S3: s3://yt-dl-mp3/J78uldnzT3s.mp3
# Checking for duplicates: z8sDFGjzgNE
# Downloading: https://www.youtube.com/watch?v=z8sDFGjzgNE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=z8sDFGjzgNE
# [youtube] z8sDFGjzgNE: Downloading webpage
# [youtube] z8sDFGjzgNE: Downloading ios player API JSON
# [youtube] z8sDFGjzgNE: Downloading mweb player API JSON
# [youtube] z8sDFGjzgNE: Downloading m3u8 information
# [info] z8sDFGjzgNE: Downloading 1 format(s): 251
# [download] Destination: downloads/z8sDFGjzgNE.webm
# [download]   9.7% of   41.36MiB at    7.50MiB/s ETA 00:04Deleting original file downloads/Nh7PXH8olI8.webm (pass -k to keep)
# Saved: downloads/Nh7PXH8olI8.mp3
# [download]  63.9% of   41.36MiB at    3.55MiB/s ETA 00:04Uploaded to S3: s3://yt-dl-mp3/Nh7PXH8olI8.mp3
# Checking for duplicates: bkC3GFBgAmY
# [download]  74.8% of   41.36MiB at    3.05MiB/s ETA 00:03Downloading: https://www.youtube.com/watch?v=bkC3GFBgAmY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bkC3GFBgAmY
# [youtube] bkC3GFBgAmY: Downloading webpage
# [download]  88.3% of   41.36MiB at    3.49MiB/s ETA 00:01[youtube] bkC3GFBgAmY: Downloading ios player API JSON
# [youtube] bkC3GFBgAmY: Downloading mweb player API JSON
# [download] 100% of   41.36MiB in 00:00:12 at 3.27MiB/s
# [ExtractAudio] Destination: downloads/z8sDFGjzgNE.mp3
# [youtube] bkC3GFBgAmY: Downloading m3u8 information
# [info] bkC3GFBgAmY: Downloading 1 format(s): 251
# Deleting original file downloads/JlQhbkzhfq8.webm (pass -k to keep)
# Saved: downloads/JlQhbkzhfq8.mp3
# [download] Destination: downloads/bkC3GFBgAmY.webm
# [download]  77.1% of   42.91MiB at    9.57MiB/s ETA 00:01Uploaded to S3: s3://yt-dl-mp3/JlQhbkzhfq8.mp3
# Checking for duplicates: iXxB83Y7s3o
# [download] 100% of   42.91MiB in 00:00:06 at 6.15MiB/s
# [ExtractAudio] Destination: downloads/bkC3GFBgAmY.mp3
# Downloading: https://www.youtube.com/watch?v=iXxB83Y7s3o
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iXxB83Y7s3o
# [youtube] iXxB83Y7s3o: Downloading webpage
# [youtube] iXxB83Y7s3o: Downloading ios player API JSON
# [youtube] iXxB83Y7s3o: Downloading mweb player API JSON
# [youtube] iXxB83Y7s3o: Downloading m3u8 information
# [info] iXxB83Y7s3o: Downloading 1 format(s): 251
# [download] Destination: downloads/iXxB83Y7s3o.webm
# [download] 100% of   40.49MiB in 00:00:11 at 3.45MiB/s
# [ExtractAudio] Destination: downloads/iXxB83Y7s3o.mp3
# Deleting original file downloads/jCuST_l5r-w.webm (pass -k to keep)
# Saved: downloads/jCuST_l5r-w.mp3
# Uploaded to S3: s3://yt-dl-mp3/jCuST_l5r-w.mp3
# Checking for duplicates: he0BOe5BMDU
# Downloading: https://www.youtube.com/watch?v=he0BOe5BMDU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=he0BOe5BMDU
# [youtube] he0BOe5BMDU: Downloading webpage
# [youtube] he0BOe5BMDU: Downloading ios player API JSON
# [youtube] he0BOe5BMDU: Downloading mweb player API JSON
# [youtube] he0BOe5BMDU: Downloading m3u8 information
# [info] he0BOe5BMDU: Downloading 1 format(s): 251
# [download] Destination: downloads/he0BOe5BMDU.webm
# [download] 100% of   39.80MiB in 00:00:05 at 7.16MiB/s
# [ExtractAudio] Destination: downloads/he0BOe5BMDU.mp3
# Deleting original file downloads/z8sDFGjzgNE.webm (pass -k to keep)
# Saved: downloads/z8sDFGjzgNE.mp3
# Uploaded to S3: s3://yt-dl-mp3/z8sDFGjzgNE.mp3
# Checking for duplicates: zukZC4yQY4E
# Downloading: https://www.youtube.com/watch?v=zukZC4yQY4E
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zukZC4yQY4E
# [youtube] zukZC4yQY4E: Downloading webpage
# [youtube] zukZC4yQY4E: Downloading ios player API JSON
# [youtube] zukZC4yQY4E: Downloading mweb player API JSON
# Deleting original file downloads/bkC3GFBgAmY.webm (pass -k to keep)
# Saved: downloads/bkC3GFBgAmY.mp3
# [youtube] zukZC4yQY4E: Downloading m3u8 information
# [info] zukZC4yQY4E: Downloading 1 format(s): 251
# [download] Destination: downloads/zukZC4yQY4E.webm
# [download]  59.2% of   39.49MiB at    7.71MiB/s ETA 00:02Uploaded to S3: s3://yt-dl-mp3/bkC3GFBgAmY.mp3
# Checking for duplicates: KBdjFFIX-j4
# [download]  84.2% of   39.49MiB at    6.41MiB/s ETA 00:00Downloading: https://www.youtube.com/watch?v=KBdjFFIX-j4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KBdjFFIX-j4
# [youtube] KBdjFFIX-j4: Downloading webpage
# [download]  99.3% of   39.49MiB at    7.14MiB/s ETA 00:00[youtube] KBdjFFIX-j4: Downloading ios player API JSON
# [download] 100% of   39.49MiB in 00:00:07 at 5.53MiB/s
# [youtube] KBdjFFIX-j4: Downloading mweb player API JSON
# [ExtractAudio] Destination: downloads/zukZC4yQY4E.mp3
# Deleting original file downloads/iXxB83Y7s3o.webm (pass -k to keep)
# Saved: downloads/iXxB83Y7s3o.mp3
# [youtube] KBdjFFIX-j4: Downloading m3u8 information
# [info] KBdjFFIX-j4: Downloading 1 format(s): 251
# [download] Destination: downloads/KBdjFFIX-j4.webm
# [download]  20.5% of   39.04MiB at    5.46MiB/s ETA 00:05Uploaded to S3: s3://yt-dl-mp3/iXxB83Y7s3o.mp3
# [download]  24.5% of   39.04MiB at    5.80MiB/s ETA 00:05Checking for duplicates: RIPUa0kM57Y
# [download]  45.0% of   39.04MiB at    6.19MiB/s ETA 00:03
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RIPUa0kM57Y
# [youtube] RIPUa0kM57Y: Downloading webpage
# [download]  60.2% of   39.04MiB at    7.15MiB/s ETA 00:02[youtube] RIPUa0kM57Y: Downloading ios player API JSON
# [youtube] RIPUa0kM57Y: Downloading mweb player API JSON
# [download] 100% of   39.04MiB in 00:00:06 at 5.75MiB/s
# [ExtractAudio] Destination: downloads/KBdjFFIX-j4.mp3
# [youtube] RIPUa0kM57Y: Downloading m3u8 information
# [info] RIPUa0kM57Y: Downloading 1 format(s): 251
# [download] Destination: downloads/RIPUa0kM57Y.webm
# [download] 100% of   48.01MiB in 00:00:10 at 4.46MiB/s
# [ExtractAudio] Destination: downloads/RIPUa0kM57Y.mp3
# Deleting original file downloads/he0BOe5BMDU.webm (pass -k to keep)
# Saved: downloads/he0BOe5BMDU.mp3
# Uploaded to S3: s3://yt-dl-mp3/he0BOe5BMDU.mp3
# Checking for duplicates: BJgX9XbiuYM
# Downloading: https://www.youtube.com/watch?v=BJgX9XbiuYM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BJgX9XbiuYM
# [youtube] BJgX9XbiuYM: Downloading webpage
# [youtube] BJgX9XbiuYM: Downloading ios player API JSON
# [youtube] BJgX9XbiuYM: Downloading mweb player API JSON
# [youtube] BJgX9XbiuYM: Downloading m3u8 information
# [info] BJgX9XbiuYM: Downloading 1 format(s): 251
# [download] Destination: downloads/BJgX9XbiuYM.webm
# [download] 100% of   40.13MiB in 00:00:10 at 3.89MiB/s
# [ExtractAudio] Destination: downloads/BJgX9XbiuYM.mp3
# Deleting original file downloads/zukZC4yQY4E.webm (pass -k to keep)
# Saved: downloads/zukZC4yQY4E.mp3
# Uploaded to S3: s3://yt-dl-mp3/zukZC4yQY4E.mp3
# Checking for duplicates: HmFVl65l9Jg
# Downloading: https://www.youtube.com/watch?v=HmFVl65l9Jg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HmFVl65l9Jg
# [youtube] HmFVl65l9Jg: Downloading webpage
# [youtube] HmFVl65l9Jg: Downloading ios player API JSON
# [youtube] HmFVl65l9Jg: Downloading mweb player API JSON
# [youtube] HmFVl65l9Jg: Downloading m3u8 information
# Deleting original file downloads/KBdjFFIX-j4.webm (pass -k to keep)
# Saved: downloads/KBdjFFIX-j4.mp3
# [info] HmFVl65l9Jg: Downloading 1 format(s): 251
# [download] Destination: downloads/HmFVl65l9Jg.webm
# [download] 100% of   41.25MiB in 00:00:04 at 9.28MiB/s
# [ExtractAudio] Destination: downloads/HmFVl65l9Jg.mp3
# Uploaded to S3: s3://yt-dl-mp3/KBdjFFIX-j4.mp3
# Checking for duplicates: eL7_JTfa6W8
# Downloading: https://www.youtube.com/watch?v=eL7_JTfa6W8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=eL7_JTfa6W8
# [youtube] eL7_JTfa6W8: Downloading webpage
# [youtube] eL7_JTfa6W8: Downloading ios player API JSON
# [youtube] eL7_JTfa6W8: Downloading mweb player API JSON
# [youtube] eL7_JTfa6W8: Downloading m3u8 information
# [info] eL7_JTfa6W8: Downloading 1 format(s): 251
# [download] Destination: downloads/eL7_JTfa6W8.webm
# [download] 100% of   40.28MiB in 00:00:05 at 7.88MiB/s
# [ExtractAudio] Destination: downloads/eL7_JTfa6W8.mp3
# Deleting original file downloads/RIPUa0kM57Y.webm (pass -k to keep)
# Saved: downloads/RIPUa0kM57Y.mp3
# Uploaded to S3: s3://yt-dl-mp3/RIPUa0kM57Y.mp3
# Checking for duplicates: Jv2naljAzHk
# Downloading: https://www.youtube.com/watch?v=Jv2naljAzHk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Jv2naljAzHk
# [youtube] Jv2naljAzHk: Downloading webpage
# [youtube] Jv2naljAzHk: Downloading ios player API JSON
# [youtube] Jv2naljAzHk: Downloading mweb player API JSON
# [youtube] Jv2naljAzHk: Downloading m3u8 information
# [info] Jv2naljAzHk: Downloading 1 format(s): 251
# [download] Destination: downloads/Jv2naljAzHk.webm
# [download]   5.0% of   39.75MiB at    5.23MiB/s ETA 00:07Deleting original file downloads/BJgX9XbiuYM.webm (pass -k to keep)
# Saved: downloads/BJgX9XbiuYM.mp3
# [download]  83.4% of   39.75MiB at    6.53MiB/s ETA 00:01Uploaded to S3: s3://yt-dl-mp3/BJgX9XbiuYM.mp3
# Checking for duplicates: NhYvGV3JgFU
# [download] 100% of   39.75MiB in 00:00:07 at 5.38MiB/s
# [ExtractAudio] Destination: downloads/Jv2naljAzHk.mp3
# Downloading: https://www.youtube.com/watch?v=NhYvGV3JgFU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NhYvGV3JgFU
# [youtube] NhYvGV3JgFU: Downloading webpage
# [youtube] NhYvGV3JgFU: Downloading ios player API JSON
# [youtube] NhYvGV3JgFU: Downloading mweb player API JSON
# [youtube] NhYvGV3JgFU: Downloading m3u8 information
# [info] NhYvGV3JgFU: Downloading 1 format(s): 251
# [download] Destination: downloads/NhYvGV3JgFU.webm
# [download] 100% of   40.95MiB in 00:00:11 at 3.56MiB/s
# [ExtractAudio] Destination: downloads/NhYvGV3JgFU.mp3
# Deleting original file downloads/HmFVl65l9Jg.webm (pass -k to keep)
# Saved: downloads/HmFVl65l9Jg.mp3
# Uploaded to S3: s3://yt-dl-mp3/HmFVl65l9Jg.mp3
# Checking for duplicates: 1B0YSrzoUf8
# Downloading: https://www.youtube.com/watch?v=1B0YSrzoUf8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1B0YSrzoUf8
# [youtube] 1B0YSrzoUf8: Downloading webpage
# [youtube] 1B0YSrzoUf8: Downloading ios player API JSON
# [youtube] 1B0YSrzoUf8: Downloading mweb player API JSON
# [youtube] 1B0YSrzoUf8: Downloading m3u8 information
# [info] 1B0YSrzoUf8: Downloading 1 format(s): 251
# Deleting original file downloads/eL7_JTfa6W8.webm (pass -k to keep)
# Saved: downloads/eL7_JTfa6W8.mp3
# [download] Destination: downloads/1B0YSrzoUf8.webm
# [download]  41.8% of   40.05MiB at    3.72MiB/s ETA 00:06Uploaded to S3: s3://yt-dl-mp3/eL7_JTfa6W8.mp3
# Checking for duplicates: 2RXmRPQqgqI
# [download]  53.5% of   40.05MiB at    2.94MiB/s ETA 00:06Downloading: https://www.youtube.com/watch?v=2RXmRPQqgqI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2RXmRPQqgqI
# [youtube] 2RXmRPQqgqI: Downloading webpage
# [download]  58.0% of   40.05MiB at    3.65MiB/s ETA 00:04[youtube] 2RXmRPQqgqI: Downloading ios player API JSON
# [youtube] 2RXmRPQqgqI: Downloading mweb player API JSON
# [download] 100% of   40.05MiB in 00:00:14 at 2.80MiB/s
# [ExtractAudio] Destination: downloads/1B0YSrzoUf8.mp3
# [youtube] 2RXmRPQqgqI: Downloading m3u8 information
# [info] 2RXmRPQqgqI: Downloading 1 format(s): 251
# [download] Destination: downloads/2RXmRPQqgqI.webm
# [download] 100% of   39.85MiB in 00:00:08 at 4.71MiB/s
# [ExtractAudio] Destination: downloads/2RXmRPQqgqI.mp3
# Deleting original file downloads/Jv2naljAzHk.webm (pass -k to keep)
# Saved: downloads/Jv2naljAzHk.mp3
# Uploaded to S3: s3://yt-dl-mp3/Jv2naljAzHk.mp3
# Checking for duplicates: 2-tnne85QpI
# Downloading: https://www.youtube.com/watch?v=2-tnne85QpI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2-tnne85QpI
# [youtube] 2-tnne85QpI: Downloading webpage
# [youtube] 2-tnne85QpI: Downloading ios player API JSON
# [youtube] 2-tnne85QpI: Downloading mweb player API JSON
# [youtube] 2-tnne85QpI: Downloading m3u8 information
# [info] 2-tnne85QpI: Downloading 1 format(s): 251
# [download] Destination: downloads/2-tnne85QpI.webm
# [download]  63.0% of   31.67MiB at    3.42MiB/s ETA 00:03Deleting original file downloads/NhYvGV3JgFU.webm (pass -k to keep)
# Saved: downloads/NhYvGV3JgFU.mp3
# [download] 100% of   31.67MiB in 00:00:09 at 3.24MiB/s
# [ExtractAudio] Destination: downloads/2-tnne85QpI.mp3
# Uploaded to S3: s3://yt-dl-mp3/NhYvGV3JgFU.mp3
# Checking for duplicates: s_Xjjh7QaX8
# Downloading: https://www.youtube.com/watch?v=s_Xjjh7QaX8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=s_Xjjh7QaX8
# [youtube] s_Xjjh7QaX8: Downloading webpage
# [youtube] s_Xjjh7QaX8: Downloading ios player API JSON
# [youtube] s_Xjjh7QaX8: Downloading mweb player API JSON
# [youtube] s_Xjjh7QaX8: Downloading m3u8 information
# [info] s_Xjjh7QaX8: Downloading 1 format(s): 251
# [download] Destination: downloads/s_Xjjh7QaX8.webm
# [download] 100% of   31.61MiB in 00:00:11 at 2.79MiB/s
# [ExtractAudio] Destination: downloads/s_Xjjh7QaX8.mp3
# Deleting original file downloads/1B0YSrzoUf8.webm (pass -k to keep)
# Saved: downloads/1B0YSrzoUf8.mp3
# Uploaded to S3: s3://yt-dl-mp3/1B0YSrzoUf8.mp3
# Checking for duplicates: cUd7sGsDMyE
# Deleting original file downloads/2RXmRPQqgqI.webm (pass -k to keep)
# Saved: downloads/2RXmRPQqgqI.mp3
# Downloading: https://www.youtube.com/watch?v=cUd7sGsDMyE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cUd7sGsDMyE
# [youtube] cUd7sGsDMyE: Downloading webpage
# [youtube] cUd7sGsDMyE: Downloading ios player API JSON
# [youtube] cUd7sGsDMyE: Downloading mweb player API JSON
# Uploaded to S3: s3://yt-dl-mp3/2RXmRPQqgqI.mp3
# Checking for duplicates: YS8tfeI26qw
# Downloading: https://www.youtube.com/watch?v=YS8tfeI26qw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YS8tfeI26qw
# [youtube] YS8tfeI26qw: Downloading webpage
# [youtube] YS8tfeI26qw: Downloading ios player API JSON
# [youtube] YS8tfeI26qw: Downloading mweb player API JSON
# [youtube] cUd7sGsDMyE: Downloading m3u8 information
# [info] cUd7sGsDMyE: Downloading 1 format(s): 251
# [download] Destination: downloads/cUd7sGsDMyE.webm
# [download]  46.8% of   41.63MiB at    6.27MiB/s ETA 00:03[youtube] YS8tfeI26qw: Downloading m3u8 information
# [download]  69.8% of   41.63MiB at    5.49MiB/s ETA 00:02[info] YS8tfeI26qw: Downloading 1 format(s): 251
# [download]  79.4% of   41.63MiB at    5.89MiB/s ETA 00:01[download] Destination: downloads/YS8tfeI26qw.webm
# [download] 100% of   41.63MiB in 00:00:08 at 4.98MiB/s
# [download]  22.6% of   43.97MiB at    5.26MiB/s ETA 00:06[ExtractAudio] Destination: downloads/cUd7sGsDMyE.mp3
# [download]  44.4% of   43.97MiB at    3.88MiB/s ETA 00:06Deleting original file downloads/2-tnne85QpI.webm (pass -k to keep)
# Saved: downloads/2-tnne85QpI.mp3
# [download]  81.8% of   43.97MiB at    2.82MiB/s ETA 00:02Uploaded to S3: s3://yt-dl-mp3/2-tnne85QpI.mp3
# Checking for duplicates: vjwMkJ3ujY4
# [download]  93.8% of   43.97MiB at    2.90MiB/s ETA 00:00Downloading: https://www.youtube.com/watch?v=vjwMkJ3ujY4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vjwMkJ3ujY4
# [youtube] vjwMkJ3ujY4: Downloading webpage
# [download] 100% of   43.97MiB in 00:00:13 at 3.35MiB/s
# [ExtractAudio] Destination: downloads/YS8tfeI26qw.mp3
# [youtube] vjwMkJ3ujY4: Downloading ios player API JSON
# [youtube] vjwMkJ3ujY4: Downloading mweb player API JSON
# [youtube] vjwMkJ3ujY4: Downloading m3u8 information
# [info] vjwMkJ3ujY4: Downloading 1 format(s): 251
# [download] Destination: downloads/vjwMkJ3ujY4.webm
# [download] 100% of   41.26MiB in 00:00:06 at 6.41MiB/s
# [ExtractAudio] Destination: downloads/vjwMkJ3ujY4.mp3
# Deleting original file downloads/s_Xjjh7QaX8.webm (pass -k to keep)
# Saved: downloads/s_Xjjh7QaX8.mp3
# Uploaded to S3: s3://yt-dl-mp3/s_Xjjh7QaX8.mp3
# Checking for duplicates: lwazkp7bSHs
# Downloading: https://www.youtube.com/watch?v=lwazkp7bSHs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lwazkp7bSHs
# [youtube] lwazkp7bSHs: Downloading webpage
# [youtube] lwazkp7bSHs: Downloading ios player API JSON
# [youtube] lwazkp7bSHs: Downloading mweb player API JSON
# [youtube] lwazkp7bSHs: Downloading m3u8 information
# [info] lwazkp7bSHs: Downloading 1 format(s): 251
# [download] Destination: downloads/lwazkp7bSHs.webm
# [download] 100% of   39.54MiB in 00:00:12 at 3.27MiB/s
# [ExtractAudio] Destination: downloads/lwazkp7bSHs.mp3
# Deleting original file downloads/cUd7sGsDMyE.webm (pass -k to keep)
# Saved: downloads/cUd7sGsDMyE.mp3
# Deleting original file downloads/YS8tfeI26qw.webm (pass -k to keep)
# Saved: downloads/YS8tfeI26qw.mp3
# Uploaded to S3: s3://yt-dl-mp3/cUd7sGsDMyE.mp3
# Checking for duplicates: ALXtVid7CnM
# Uploaded to S3: s3://yt-dl-mp3/YS8tfeI26qw.mp3
# Checking for duplicates: q0YXyaPdDzo
# Downloading: https://www.youtube.com/watch?v=ALXtVid7CnM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ALXtVid7CnM
# [youtube] ALXtVid7CnM: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=q0YXyaPdDzo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=q0YXyaPdDzo
# [youtube] q0YXyaPdDzo: Downloading webpage
# Deleting original file downloads/vjwMkJ3ujY4.webm (pass -k to keep)
# Saved: downloads/vjwMkJ3ujY4.mp3
# [youtube] ALXtVid7CnM: Downloading ios player API JSON
# [youtube] ALXtVid7CnM: Downloading mweb player API JSON
# [youtube] q0YXyaPdDzo: Downloading ios player API JSON
# [youtube] q0YXyaPdDzo: Downloading mweb player API JSON
# Uploaded to S3: s3://yt-dl-mp3/vjwMkJ3ujY4.mp3
# Checking for duplicates: plJb6153KB0
# [youtube] ALXtVid7CnM: Downloading m3u8 information
# Downloading: https://www.youtube.com/watch?v=plJb6153KB0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=plJb6153KB0
# [youtube] plJb6153KB0: Downloading webpage
# [info] ALXtVid7CnM: Downloading 1 format(s): 251
# [youtube] q0YXyaPdDzo: Downloading m3u8 information
# [download] Destination: downloads/ALXtVid7CnM.webm
# [download]   0.3% of   35.93MiB at  566.77KiB/s ETA 01:04[youtube] plJb6153KB0: Downloading ios player API JSON
# [download]   5.6% of   35.93MiB at    5.33MiB/s ETA 00:06[info] q0YXyaPdDzo: Downloading 1 format(s): 251
# [youtube] plJb6153KB0: Downloading mweb player API JSON
# [download] Destination: downloads/q0YXyaPdDzo.webm
# [download] 100% of   42.23MiB in 00:00:03 at 13.51MiB/s
# [ExtractAudio] Destination: downloads/q0YXyaPdDzo.mp3
# [download]  77.1% of   35.93MiB at    4.27MiB/s ETA 00:01[youtube] plJb6153KB0: Downloading m3u8 information
# [download]  83.3% of   35.93MiB at    2.51MiB/s ETA 00:02[info] plJb6153KB0: Downloading 1 format(s): 251
# [download]  93.7% of   35.93MiB at    4.05MiB/s ETA 00:00[download] Destination: downloads/plJb6153KB0.webm
# [download] 100% of   35.93MiB in 00:00:10 at 3.48MiB/s
# [download]  11.2% of   35.55MiB at    8.74MiB/s ETA 00:03[ExtractAudio] Destination: downloads/ALXtVid7CnM.mp3
# [download]  94.2% of   35.55MiB at   12.72MiB/s ETA 00:00Deleting original file downloads/lwazkp7bSHs.webm (pass -k to keep)
# Saved: downloads/lwazkp7bSHs.mp3
# [download] 100% of   35.55MiB in 00:00:03 at 9.20MiB/s
# [ExtractAudio] Destination: downloads/plJb6153KB0.mp3
# Uploaded to S3: s3://yt-dl-mp3/lwazkp7bSHs.mp3
# Checking for duplicates: fb0WDXPaMDk
# Downloading: https://www.youtube.com/watch?v=fb0WDXPaMDk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fb0WDXPaMDk
# [youtube] fb0WDXPaMDk: Downloading webpage
# [youtube] fb0WDXPaMDk: Downloading ios player API JSON
# [youtube] fb0WDXPaMDk: Downloading mweb player API JSON
# [youtube] fb0WDXPaMDk: Downloading m3u8 information
# [info] fb0WDXPaMDk: Downloading 1 format(s): 251
# [download] Destination: downloads/fb0WDXPaMDk.webm
# [download] 100% of   38.24MiB in 00:00:04 at 8.08MiB/s
# [ExtractAudio] Destination: downloads/fb0WDXPaMDk.mp3
# Deleting original file downloads/ALXtVid7CnM.webm (pass -k to keep)
# Saved: downloads/ALXtVid7CnM.mp3
# Deleting original file downloads/plJb6153KB0.webm (pass -k to keep)
# Saved: downloads/plJb6153KB0.mp3
# Deleting original file downloads/q0YXyaPdDzo.webm (pass -k to keep)
# Saved: downloads/q0YXyaPdDzo.mp3
# Uploaded to S3: s3://yt-dl-mp3/ALXtVid7CnM.mp3
# Checking for duplicates: oUTIRVb64R0
# Downloading: https://www.youtube.com/watch?v=oUTIRVb64R0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oUTIRVb64R0
# [youtube] oUTIRVb64R0: Downloading webpage
# Uploaded to S3: s3://yt-dl-mp3/plJb6153KB0.mp3
# Checking for duplicates: 0Xem1YCuGYU
# [youtube] oUTIRVb64R0: Downloading ios player API JSON
# Uploaded to S3: s3://yt-dl-mp3/q0YXyaPdDzo.mp3
# [youtube] oUTIRVb64R0: Downloading mweb player API JSON
# Checking for duplicates: X291JHcTDVQ
# Downloading: https://www.youtube.com/watch?v=0Xem1YCuGYU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0Xem1YCuGYU
# [youtube] 0Xem1YCuGYU: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=X291JHcTDVQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X291JHcTDVQ
# [youtube] X291JHcTDVQ: Downloading webpage
# [youtube] 0Xem1YCuGYU: Downloading ios player API JSON
# [youtube] 0Xem1YCuGYU: Downloading mweb player API JSON
# [youtube] X291JHcTDVQ: Downloading ios player API JSON
# [youtube] X291JHcTDVQ: Downloading mweb player API JSON
# [youtube] oUTIRVb64R0: Downloading m3u8 information
# Deleting original file downloads/fb0WDXPaMDk.webm (pass -k to keep)
# Saved: downloads/fb0WDXPaMDk.mp3
# [info] oUTIRVb64R0: Downloading 1 format(s): 251
# [youtube] X291JHcTDVQ: Downloading m3u8 information
# [youtube] 0Xem1YCuGYU: Downloading m3u8 information
# [download] Destination: downloads/oUTIRVb64R0.webm
# [download]  11.8% of   33.97MiB at    7.33MiB/s ETA 00:04[info] X291JHcTDVQ: Downloading 1 format(s): 251
# [download]  23.5% of   33.97MiB at   11.68MiB/s ETA 00:02[info] 0Xem1YCuGYU: Downloading 1 format(s): 251
# [download]  34.0% of   33.97MiB at    7.76MiB/s ETA 00:02[download] Destination: downloads/0Xem1YCuGYU.webm
# [download]  60.5% of   33.97MiB at    5.41MiB/s ETA 00:02[download] Destination: downloads/X291JHcTDVQ.webm
# [download] 100% of   33.97MiB in 00:00:03 at 10.34MiB/s
# [download]  59.4% of   33.60MiB at   10.13MiB/s ETA 00:01[ExtractAudio] Destination: downloads/oUTIRVb64R0.mp3
# [download] 100% of   33.60MiB in 00:00:03 at 9.04MiB/s
# [download]  64.7% of   33.08MiB at    5.02MiB/s ETA 00:02Uploaded to S3: s3://yt-dl-mp3/fb0WDXPaMDk.mp3
# [download]  70.7% of   33.08MiB at    6.63MiB/s ETA 00:01[ExtractAudio] Destination: downloads/0Xem1YCuGYU.mp3
# Checking for duplicates: h7Q61dOPeJ8
# [download] 100% of   33.08MiB in 00:00:05 at 5.80MiB/s
# [ExtractAudio] Destination: downloads/X291JHcTDVQ.mp3
# Downloading: https://www.youtube.com/watch?v=h7Q61dOPeJ8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=h7Q61dOPeJ8
# [youtube] h7Q61dOPeJ8: Downloading webpage
# [youtube] h7Q61dOPeJ8: Downloading ios player API JSON
# [youtube] h7Q61dOPeJ8: Downloading mweb player API JSON
# [youtube] h7Q61dOPeJ8: Downloading m3u8 information
# [info] h7Q61dOPeJ8: Downloading 1 format(s): 251
# [download] Destination: downloads/h7Q61dOPeJ8.webm
# [download] 100% of   32.84MiB in 00:00:04 at 6.79MiB/s
# [ExtractAudio] Destination: downloads/h7Q61dOPeJ8.mp3
# Deleting original file downloads/oUTIRVb64R0.webm (pass -k to keep)
# Saved: downloads/oUTIRVb64R0.mp3
# Deleting original file downloads/X291JHcTDVQ.webm (pass -k to keep)
# Saved: downloads/X291JHcTDVQ.mp3
# Deleting original file downloads/0Xem1YCuGYU.webm (pass -k to keep)
# Saved: downloads/0Xem1YCuGYU.mp3
# Uploaded to S3: s3://yt-dl-mp3/X291JHcTDVQ.mp3
# Checking for duplicates: RzuPgsEKjxEUploaded to S3: s3://yt-dl-mp3/oUTIRVb64R0.mp3
#
# Checking for duplicates: l4v5jt0IAiM
# Uploaded to S3: s3://yt-dl-mp3/0Xem1YCuGYU.mp3
# Checking for duplicates: bjjgwZtFcL4
# Deleting original file downloads/h7Q61dOPeJ8.webm (pass -k to keep)
# Saved: downloads/h7Q61dOPeJ8.mp3
# Downloading: https://www.youtube.com/watch?v=RzuPgsEKjxE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RzuPgsEKjxE
# [youtube] RzuPgsEKjxE: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=l4v5jt0IAiM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=l4v5jt0IAiM
# [youtube] l4v5jt0IAiM: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=bjjgwZtFcL4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bjjgwZtFcL4
# [youtube] bjjgwZtFcL4: Downloading webpage
# [youtube] RzuPgsEKjxE: Downloading ios player API JSON
# [youtube] l4v5jt0IAiM: Downloading ios player API JSON
# [youtube] RzuPgsEKjxE: Downloading mweb player API JSON
# [youtube] l4v5jt0IAiM: Downloading mweb player API JSON
# [youtube] bjjgwZtFcL4: Downloading ios player API JSON
# [youtube] bjjgwZtFcL4: Downloading mweb player API JSON
# Uploaded to S3: s3://yt-dl-mp3/h7Q61dOPeJ8.mp3
# [youtube] RzuPgsEKjxE: Downloading m3u8 information
# [youtube] bjjgwZtFcL4: Downloading m3u8 information
# Checking for duplicates: aoXMat5FT1Y
# [youtube] l4v5jt0IAiM: Downloading m3u8 information
# [info] RzuPgsEKjxE: Downloading 1 format(s): 251
# [info] bjjgwZtFcL4: Downloading 1 format(s): 251
# [info] l4v5jt0IAiM: Downloading 1 format(s): 251
# [download] Destination: downloads/l4v5jt0IAiM.webm
# [download]   2.2% of   46.12MiB at    8.82MiB/s ETA 00:05Downloading: https://www.youtube.com/watch?v=aoXMat5FT1Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aoXMat5FT1Y
# [youtube] aoXMat5FT1Y: Downloading webpage
# [download] Destination: downloads/bjjgwZtFcL4.webm
# [download]   0.1% of   32.50MiB at    1.93MiB/s ETA 00:16[download] Destination: downloads/RzuPgsEKjxE.webm
# [download]  12.5% of   32.05MiB at    6.42MiB/s ETA 00:04[youtube] aoXMat5FT1Y: Downloading ios player API JSON
# [download]  21.1% of   46.12MiB at    7.00MiB/s ETA 00:05[youtube] aoXMat5FT1Y: Downloading mweb player API JSON
# [download]  60.1% of   46.12MiB at    6.83MiB/s ETA 00:02[youtube] aoXMat5FT1Y: Downloading m3u8 information
# [download] 100% of   32.05MiB in 00:00:05 at 5.40MiB/s
# [download]  63.2% of   32.50MiB at    3.68MiB/s ETA 00:03[ExtractAudio] Destination: downloads/RzuPgsEKjxE.mp3
# [info] aoXMat5FT1Y: Downloading 1 format(s): 251
# [download]  72.4% of   32.50MiB at    5.03MiB/s ETA 00:01[download] Destination: downloads/aoXMat5FT1Y.webm
# [download] 100% of   46.12MiB in 00:00:07 at 5.77MiB/s
# [download]  85.1% of   32.10MiB at   28.81MiB/s ETA 00:00[ExtractAudio] Destination: downloads/l4v5jt0IAiM.mp3
# [download] 100% of   32.50MiB in 00:00:08 at 3.65MiB/s
#
# [ExtractAudio] Destination: downloads/bjjgwZtFcL4.mp3
# [ExtractAudio] Destination: downloads/aoXMat5FT1Y.mp3
# Deleting original file downloads/RzuPgsEKjxE.webm (pass -k to keep)
# Saved: downloads/RzuPgsEKjxE.mp3
# Deleting original file downloads/aoXMat5FT1Y.webm (pass -k to keep)
# Saved: downloads/aoXMat5FT1Y.mp3
# Deleting original file downloads/bjjgwZtFcL4.webm (pass -k to keep)
# Saved: downloads/bjjgwZtFcL4.mp3
# Uploaded to S3: s3://yt-dl-mp3/RzuPgsEKjxE.mp3
# Checking for duplicates: DJBsatrHKsA
# Downloading: https://www.youtube.com/watch?v=DJBsatrHKsA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DJBsatrHKsA
# [youtube] DJBsatrHKsA: Downloading webpage
# [youtube] DJBsatrHKsA: Downloading ios player API JSON
# [youtube] DJBsatrHKsA: Downloading mweb player API JSON
# Uploaded to S3: s3://yt-dl-mp3/bjjgwZtFcL4.mp3
# Checking for duplicates: _3hjwEKCxxMUploaded to S3: s3://yt-dl-mp3/aoXMat5FT1Y.mp3
#
# Checking for duplicates: PkwuDNgfaAQ
# Downloading: https://www.youtube.com/watch?v=_3hjwEKCxxM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_3hjwEKCxxM
# [youtube] _3hjwEKCxxM: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=PkwuDNgfaAQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PkwuDNgfaAQ
# [youtube] PkwuDNgfaAQ: Downloading webpage
# [youtube] _3hjwEKCxxM: Downloading ios player API JSON
# [youtube] _3hjwEKCxxM: Downloading mweb player API JSON
# [youtube] PkwuDNgfaAQ: Downloading ios player API JSON
# [youtube] PkwuDNgfaAQ: Downloading mweb player API JSON
# [youtube] DJBsatrHKsA: Downloading m3u8 information
# [info] DJBsatrHKsA: Downloading 1 format(s): 251
# [download] Destination: downloads/DJBsatrHKsA.webm
# [download]  37.4% of   31.94MiB at    4.99MiB/s ETA 00:04[youtube] _3hjwEKCxxM: Downloading m3u8 information
# [download]  62.3% of   31.94MiB at    7.32MiB/s ETA 00:01[youtube] PkwuDNgfaAQ: Downloading m3u8 information
# [download]  62.4% of   31.94MiB at    1.72MiB/s ETA 00:06[info] _3hjwEKCxxM: Downloading 1 format(s): 251
# [download]  74.8% of   31.94MiB at   10.41MiB/s ETA 00:00[download] Destination: downloads/_3hjwEKCxxM.webm
# [download]   2.2% of   45.43MiB at    3.25MiB/s ETA 00:13[info] PkwuDNgfaAQ: Downloading 1 format(s): 251
# [download] 100% of   31.94MiB in 00:00:06 at 5.24MiB/s
# Deleting original file downloads/l4v5jt0IAiM.webm (pass -k to keep)
# [download]   4.4% of   45.43MiB at    1.88MiB/s ETA 00:23Saved: downloads/l4v5jt0IAiM.mp3
# [ExtractAudio] Destination: downloads/DJBsatrHKsA.mp3
# [download] Destination: downloads/PkwuDNgfaAQ.webm
# [download]  55.6% of   45.43MiB at    3.78MiB/s ETA 00:05Uploaded to S3: s3://yt-dl-mp3/l4v5jt0IAiM.mp3
# Checking for duplicates: 3joJ4xgxm6M
# [download]  80.6% of   40.93MiB at    5.22MiB/s ETA 00:01Downloading: https://www.youtube.com/watch?v=3joJ4xgxm6M
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3joJ4xgxm6M
# [youtube] 3joJ4xgxm6M: Downloading webpage
# [download]  96.8% of   40.93MiB at   13.51MiB/s ETA 00:00[youtube] 3joJ4xgxm6M: Downloading ios player API JSON
# [youtube] 3joJ4xgxm6M: Downloading mweb player API JSON
# [download] 100% of   40.93MiB in 00:00:10 at 3.93MiB/s
# [download]  85.9% of   45.43MiB at    3.98MiB/s ETA 00:01[ExtractAudio] Destination: downloads/PkwuDNgfaAQ.mp3
# [download] 100% of   45.43MiB in 00:00:13 at 3.34MiB/s
# [ExtractAudio] Destination: downloads/_3hjwEKCxxM.mp3
# [youtube] 3joJ4xgxm6M: Downloading m3u8 information
# [info] 3joJ4xgxm6M: Downloading 1 format(s): 251
# [download] Destination: downloads/3joJ4xgxm6M.webm
# [download] 100% of   50.44MiB in 00:00:13 at 3.65MiB/s
# [ExtractAudio] Destination: downloads/3joJ4xgxm6M.mp3
# Deleting original file downloads/DJBsatrHKsA.webm (pass -k to keep)
# Saved: downloads/DJBsatrHKsA.mp3
# Uploaded to S3: s3://yt-dl-mp3/DJBsatrHKsA.mp3
# Checking for duplicates: cXaT-PTWpKo
# Downloading: https://www.youtube.com/watch?v=cXaT-PTWpKo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cXaT-PTWpKo
# [youtube] cXaT-PTWpKo: Downloading webpage
# [youtube] cXaT-PTWpKo: Downloading ios player API JSON
# [youtube] cXaT-PTWpKo: Downloading mweb player API JSON
# [youtube] cXaT-PTWpKo: Downloading m3u8 information
# [info] cXaT-PTWpKo: Downloading 1 format(s): 251
# [download] Destination: downloads/cXaT-PTWpKo.webm
# [download] 100% of   52.82MiB in 00:00:06 at 8.74MiB/s
# [ExtractAudio] Destination: downloads/cXaT-PTWpKo.mp3
# Deleting original file downloads/PkwuDNgfaAQ.webm (pass -k to keep)
# Saved: downloads/PkwuDNgfaAQ.mp3
# Uploaded to S3: s3://yt-dl-mp3/PkwuDNgfaAQ.mp3
# Checking for duplicates: PtOeAcvT-Jw
# Downloading: https://www.youtube.com/watch?v=PtOeAcvT-Jw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PtOeAcvT-Jw
# [youtube] PtOeAcvT-Jw: Downloading webpage
# Deleting original file downloads/_3hjwEKCxxM.webm (pass -k to keep)
# Saved: downloads/_3hjwEKCxxM.mp3
# [youtube] PtOeAcvT-Jw: Downloading ios player API JSON
# [youtube] PtOeAcvT-Jw: Downloading mweb player API JSON
# [youtube] PtOeAcvT-Jw: Downloading m3u8 information
# [info] PtOeAcvT-Jw: Downloading 1 format(s): 251
# Uploaded to S3: s3://yt-dl-mp3/_3hjwEKCxxM.mp3
# Checking for duplicates: 3R7Vv-Pr0e4
# [download] Destination: downloads/PtOeAcvT-Jw.webm
# [download]  21.6% of   51.05MiB at    1.52MiB/s ETA 00:26Downloading: https://www.youtube.com/watch?v=3R7Vv-Pr0e4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3R7Vv-Pr0e4
# [youtube] 3R7Vv-Pr0e4: Downloading webpage
# [download]  28.7% of   51.05MiB at    2.87MiB/s ETA 00:12[youtube] 3R7Vv-Pr0e4: Downloading ios player API JSON
# [download]  38.1% of   51.05MiB at    4.57MiB/s ETA 00:06[youtube] 3R7Vv-Pr0e4: Downloading mweb player API JSON
# [download]  42.0% of   51.05MiB at   27.67MiB/s ETA 00:01Deleting original file downloads/3joJ4xgxm6M.webm (pass -k to keep)
# Saved: downloads/3joJ4xgxm6M.mp3
# [download]  77.7% of   51.05MiB at    8.02MiB/s ETA 00:01[youtube] 3R7Vv-Pr0e4: Downloading m3u8 information
# [download]  79.6% of   51.05MiB at    3.73MiB/s ETA 00:02Uploaded to S3: s3://yt-dl-mp3/3joJ4xgxm6M.mp3
# Checking for duplicates: Velz8zROw_4
# [download]  83.5% of   51.05MiB at    4.20MiB/s ETA 00:02[info] 3R7Vv-Pr0e4: Downloading 1 format(s): 251
# [download]  94.8% of   51.05MiB at    4.37MiB/s ETA 00:00[download] Destination: downloads/3R7Vv-Pr0e4.webm
# [download]   2.3% of   44.06MiB at    4.24MiB/s ETA 00:10
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Velz8zROw_4
# [youtube] Velz8zROw_4: Downloading webpage
# [download] 100% of   51.05MiB in 00:00:11 at 4.57MiB/s
# [youtube] Velz8zROw_4: Downloading ios player API JSON
# [download]  16.6% of   44.06MiB at    5.51MiB/s ETA 00:06[youtube] Velz8zROw_4: Downloading mweb player API JSON
# [ExtractAudio] Destination: downloads/PtOeAcvT-Jw.mp3
# [download]  84.3% of   44.06MiB at    4.95MiB/s ETA 00:01[youtube] Velz8zROw_4: Downloading m3u8 information
# [download]  92.5% of   44.06MiB at    4.28MiB/s ETA 00:00[info] Velz8zROw_4: Downloading 1 format(s): 251
# [download] 100% of   44.06MiB in 00:00:09 at 4.64MiB/s
# [download] Destination: downloads/Velz8zROw_4.webm
# [download]   3.6% of   55.28MiB at   17.23MiB/s ETA 00:03[ExtractAudio] Destination: downloads/3R7Vv-Pr0e4.mp3
# [download] 100% of   55.28MiB in 00:00:08 at 6.37MiB/s
# [ExtractAudio] Destination: downloads/Velz8zROw_4.mp3
# Deleting original file downloads/cXaT-PTWpKo.webm (pass -k to keep)
# Saved: downloads/cXaT-PTWpKo.mp3
# Uploaded to S3: s3://yt-dl-mp3/cXaT-PTWpKo.mp3
# Checking for duplicates: DBzdRBM8fBs
# Downloading: https://www.youtube.com/watch?v=DBzdRBM8fBs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DBzdRBM8fBs
# [youtube] DBzdRBM8fBs: Downloading webpage
# [youtube] DBzdRBM8fBs: Downloading ios player API JSON
# [youtube] DBzdRBM8fBs: Downloading mweb player API JSON
# [youtube] DBzdRBM8fBs: Downloading m3u8 information
# [info] DBzdRBM8fBs: Downloading 1 format(s): 251
# [download] Destination: downloads/DBzdRBM8fBs.webm
# [download] 100% of   51.37MiB in 00:00:13 at 3.94MiB/s
# [ExtractAudio] Destination: downloads/DBzdRBM8fBs.mp3
# Deleting original file downloads/PtOeAcvT-Jw.webm (pass -k to keep)
# Saved: downloads/PtOeAcvT-Jw.mp3
# Uploaded to S3: s3://yt-dl-mp3/PtOeAcvT-Jw.mp3
# Checking for duplicates: 6zaWRQMi5g8
# Downloading: https://www.youtube.com/watch?v=6zaWRQMi5g8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6zaWRQMi5g8
# [youtube] 6zaWRQMi5g8: Downloading webpage
# [youtube] 6zaWRQMi5g8: Downloading ios player API JSON
# [youtube] 6zaWRQMi5g8: Downloading mweb player API JSON
# Deleting original file downloads/3R7Vv-Pr0e4.webm (pass -k to keep)
# Saved: downloads/3R7Vv-Pr0e4.mp3
# Uploaded to S3: s3://yt-dl-mp3/3R7Vv-Pr0e4.mp3
# Checking for duplicates: uijTbcorZ5s
# [youtube] 6zaWRQMi5g8: Downloading m3u8 information
# Downloading: https://www.youtube.com/watch?v=uijTbcorZ5s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uijTbcorZ5s
# [youtube] uijTbcorZ5s: Downloading webpage
# [info] 6zaWRQMi5g8: Downloading 1 format(s): 251
# [download] Destination: downloads/6zaWRQMi5g8.webm
# [download]   0.1% of   46.15MiB at  412.08KiB/s ETA 01:54[youtube] uijTbcorZ5s: Downloading ios player API JSON
# [download]   1.1% of   46.15MiB at    1.87MiB/s ETA 00:24[youtube] uijTbcorZ5s: Downloading mweb player API JSON
# [download]  28.7% of   46.15MiB at    3.35MiB/s ETA 00:09Deleting original file downloads/Velz8zROw_4.webm (pass -k to keep)
# Saved: downloads/Velz8zROw_4.mp3
# [download]  36.1% of   46.15MiB at    3.38MiB/s ETA 00:08[youtube] uijTbcorZ5s: Downloading m3u8 information
# [download]  43.0% of   46.15MiB at    3.58MiB/s ETA 00:07[info] uijTbcorZ5s: Downloading 1 format(s): 251
# [download]  44.6% of   46.15MiB at    1.66MiB/s ETA 00:15[download] Destination: downloads/uijTbcorZ5s.webm
# [download]  79.6% of   46.15MiB at    4.08MiB/s ETA 00:02Uploaded to S3: s3://yt-dl-mp3/Velz8zROw_4.mp3
# [download]  84.5% of   46.15MiB at    4.45MiB/s ETA 00:01Checking for duplicates: ygi8xvM2JAw
# [download]  92.1% of   46.15MiB at    3.16MiB/s ETA 00:01Downloading: https://www.youtube.com/watch?v=ygi8xvM2JAw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ygi8xvM2JAw
# [youtube] ygi8xvM2JAw: Downloading webpage
# [download] 100% of   46.15MiB in 00:00:13 at 3.32MiB/s
# [ExtractAudio] Destination: downloads/6zaWRQMi5g8.mp3
# [download]  40.9% of   54.65MiB at    2.23MiB/s ETA 00:14[youtube] ygi8xvM2JAw: Downloading ios player API JSON
# [youtube] ygi8xvM2JAw: Downloading mweb player API JSON
# [download]  74.8% of   54.65MiB at    2.72MiB/s ETA 00:05[youtube] ygi8xvM2JAw: Downloading m3u8 information
# [download]  78.0% of   54.65MiB at    2.75MiB/s ETA 00:04[info] ygi8xvM2JAw: Downloading 1 format(s): 251
# ...
# Uploaded to S3: s3://yt-dl-mp3/BYLOo-O_p_M.mp3
# Checking for duplicates: 5GgyDsYZ5oU
# Deleting original file downloads/pniSsf9qJzU.webm (pass -k to keep)
# Saved: downloads/pniSsf9qJzU.mp3
# Downloading: https://www.youtube.com/watch?v=cFBb-sYfRLA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cFBb-sYfRLA
# [youtube] cFBb-sYfRLA: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=5GgyDsYZ5oU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5GgyDsYZ5oU
# [youtube] 5GgyDsYZ5oU: Downloading webpage
# [youtube] cFBb-sYfRLA: Downloading ios player API JSON
# [youtube] 5GgyDsYZ5oU: Downloading ios player API JSON
# [youtube] cFBb-sYfRLA: Downloading mweb player API JSON
# [youtube] 5GgyDsYZ5oU: Downloading mweb player API JSON
# Uploaded to S3: s3://yt-dl-mp3/pniSsf9qJzU.mp3
# Checking for duplicates: fwvp3mnf7kE
# Downloading: https://www.youtube.com/watch?v=fwvp3mnf7kE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fwvp3mnf7kE
# [youtube] fwvp3mnf7kE: Downloading webpage
# [youtube] fwvp3mnf7kE: Downloading ios player API JSON
# [youtube] fwvp3mnf7kE: Downloading mweb player API JSON
# [youtube] 5GgyDsYZ5oU: Downloading m3u8 information
# [youtube] cFBb-sYfRLA: Downloading m3u8 information
# [info] 5GgyDsYZ5oU: Downloading 1 format(s): 251
# [info] cFBb-sYfRLA: Downloading 1 format(s): 251
# Deleting original file downloads/s3XNF-93xzM.webm (pass -k to keep)
# Saved: downloads/s3XNF-93xzM.mp3
# [download] Destination: downloads/5GgyDsYZ5oU.webm
# [download]   4.8% of   41.82MiB at   12.03MiB/s ETA 00:03[download] Destination: downloads/cFBb-sYfRLA.webm
# [download] 100% of   41.82MiB in 00:00:02 at 19.51MiB/s
# [download]  32.0% of   42.21MiB at   15.00MiB/s ETA 00:01[ExtractAudio] Destination: downloads/5GgyDsYZ5oU.mp3
# [youtube] fwvp3mnf7kE: Downloading m3u8 information
# [download]  69.9% of   42.21MiB at    2.34MiB/s ETA 00:05[info] fwvp3mnf7kE: Downloading 1 format(s): 251
# [download]  92.6% of   42.21MiB at  Unknown B/s ETA Unknown[download] Destination: downloads/fwvp3mnf7kE.webm
# [download]   6.6% of   30.19MiB at    7.27MiB/s ETA 00:03
# [download]  13.2% of   30.19MiB at    8.75MiB/s ETA 00:02[ExtractAudio] Destination: downloads/cFBb-sYfRLA.mp3
# [download]  58.6% of   30.19MiB at    8.11MiB/s ETA 00:01Uploaded to S3: s3://yt-dl-mp3/s3XNF-93xzM.mp3
# Checking for duplicates: lcwZ0S8NO4c
# [download] 100% of   30.19MiB in 00:00:04 at 7.12MiB/s
# Downloading: https://www.youtube.com/watch?v=lcwZ0S8NO4c
# [youtube] Extracting URL: https://www.youtube.com/watch?v=lcwZ0S8NO4c
# [youtube] lcwZ0S8NO4c: Downloading webpage
# [ExtractAudio] Destination: downloads/fwvp3mnf7kE.mp3
# [youtube] lcwZ0S8NO4c: Downloading ios player API JSON
# [youtube] lcwZ0S8NO4c: Downloading mweb player API JSON
# [youtube] lcwZ0S8NO4c: Downloading m3u8 information
# [info] lcwZ0S8NO4c: Downloading 1 format(s): 251
# [download] Destination: downloads/lcwZ0S8NO4c.webm
# [download] 100% of   30.94MiB in 00:00:09 at 3.19MiB/s
# [ExtractAudio] Destination: downloads/lcwZ0S8NO4c.mp3
# Deleting original file downloads/fwvp3mnf7kE.webm (pass -k to keep)
# Saved: downloads/fwvp3mnf7kE.mp3
# Uploaded to S3: s3://yt-dl-mp3/fwvp3mnf7kE.mp3
# Checking for duplicates: RA-rwgTXsWE
# Downloading: https://www.youtube.com/watch?v=RA-rwgTXsWE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RA-rwgTXsWE
# [youtube] RA-rwgTXsWE: Downloading webpage
# [youtube] RA-rwgTXsWE: Downloading ios player API JSON
# [youtube] RA-rwgTXsWE: Downloading mweb player API JSON
# [youtube] RA-rwgTXsWE: Downloading m3u8 information
# [info] RA-rwgTXsWE: Downloading 1 format(s): 251
# [download] Destination: downloads/RA-rwgTXsWE.webm
# [download]  31.6% of   32.23MiB at    2.06MiB/s ETA 00:10Deleting original file downloads/lcwZ0S8NO4c.webm (pass -k to keep)
# [download]  33.2% of   32.23MiB at    3.56MiB/s ETA 00:06Saved: downloads/lcwZ0S8NO4c.mp3
# [download]  54.9% of   32.23MiB at    9.88MiB/s ETA 00:01Deleting original file downloads/5GgyDsYZ5oU.webm (pass -k to keep)
# Saved: downloads/5GgyDsYZ5oU.mp3
# [download] 100% of   32.23MiB in 00:00:04 at 7.55MiB/s
# [ExtractAudio] Destination: downloads/RA-rwgTXsWE.mp3
# Deleting original file downloads/cFBb-sYfRLA.webm (pass -k to keep)
# Saved: downloads/cFBb-sYfRLA.mp3
# Uploaded to S3: s3://yt-dl-mp3/lcwZ0S8NO4c.mp3
# Checking for duplicates: SVz93GOnXsM
# Uploaded to S3: s3://yt-dl-mp3/5GgyDsYZ5oU.mp3
# Checking for duplicates: gy4Xka9ga4A
# Downloading: https://www.youtube.com/watch?v=SVz93GOnXsM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=SVz93GOnXsM
# [youtube] SVz93GOnXsM: Downloading webpage
# Downloading: https://www.youtube.com/watch?v=gy4Xka9ga4A
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gy4Xka9ga4A
# [youtube] gy4Xka9ga4A: Downloading webpage
# [youtube] SVz93GOnXsM: Downloading ios player API JSON
# [youtube] SVz93GOnXsM: Downloading mweb player API JSON
# [youtube] gy4Xka9ga4A: Downloading ios player API JSON
# [youtube] gy4Xka9ga4A: Downloading mweb player API JSON
# Uploaded to S3: s3://yt-dl-mp3/cFBb-sYfRLA.mp3
# Checking for duplicates: IfD_cskfokg
# Downloading: https://www.youtube.com/watch?v=IfD_cskfokg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IfD_cskfokg
# [youtube] IfD_cskfokg: Downloading webpage
# [youtube] IfD_cskfokg: Downloading ios player API JSON
# [youtube] IfD_cskfokg: Downloading mweb player API JSON
# [youtube] SVz93GOnXsM: Downloading m3u8 information
# [info] SVz93GOnXsM: Downloading 1 format(s): 251
# [youtube] gy4Xka9ga4A: Downloading m3u8 information
# [download] Destination: downloads/SVz93GOnXsM.webm
# [download]   8.9% of   11.19MiB at    1.65MiB/s ETA 00:06[info] gy4Xka9ga4A: Downloading 1 format(s): 251
# [download]  35.7% of   11.19MiB at    3.22MiB/s ETA 00:02[download] Destination: downloads/gy4Xka9ga4A.webm
# [download]  88.6% of   11.19MiB at    3.39MiB/s ETA 00:00[youtube] IfD_cskfokg: Downloading m3u8 information
# [download] 100% of   11.19MiB in 00:00:03 at 2.83MiB/s
# [ExtractAudio] Destination: downloads/SVz93GOnXsM.mp3
# [download]  53.8% of   35.81MiB at  332.51KiB/s ETA 00:50  [info] IfD_cskfokg: Downloading 1 format(s): 251
# [download]  65.0% of   35.81MiB at    9.72MiB/s ETA 00:01[download] Destination: downloads/IfD_cskfokg.webm
# [download] 100% of   35.81MiB in 00:00:05 at 6.78MiB/s
# [download]  29.9% of   33.19MiB at    4.73MiB/s ETA 00:04[ExtractAudio] Destination: downloads/gy4Xka9ga4A.mp3
# [download] 100% of   33.19MiB in 00:00:07 at 4.73MiB/s
# [ExtractAudio] Destination: downloads/IfD_cskfokg.mp3
# Deleting original file downloads/SVz93GOnXsM.webm (pass -k to keep)
# Saved: downloads/SVz93GOnXsM.mp3
# Uploaded to S3: s3://yt-dl-mp3/SVz93GOnXsM.mp3
# Checking for duplicates: u5hj3tPlmAs
# Downloading: https://www.youtube.com/watch?v=u5hj3tPlmAs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=u5hj3tPlmAs
# [youtube] u5hj3tPlmAs: Downloading webpage
# [youtube] u5hj3tPlmAs: Downloading ios player API JSON
# [youtube] u5hj3tPlmAs: Downloading mweb player API JSON
# [youtube] u5hj3tPlmAs: Downloading m3u8 information
# [info] u5hj3tPlmAs: Downloading 1 format(s): 251
# [download] Destination: downloads/u5hj3tPlmAs.webm
# [download] 100% of   35.69MiB in 00:00:03 at 9.43MiB/s
# [ExtractAudio] Destination: downloads/u5hj3tPlmAs.mp3
# Deleting original file downloads/RA-rwgTXsWE.webm (pass -k to keep)
# Saved: downloads/RA-rwgTXsWE.mp3
# Uploaded to S3: s3://yt-dl-mp3/RA-rwgTXsWE.mp3
# Checking for duplicates: FL7Vbwtin8E
# Downloading: https://www.youtube.com/watch?v=FL7Vbwtin8E
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FL7Vbwtin8E
# [youtube] FL7Vbwtin8E: Downloading webpage
# [youtube] FL7Vbwtin8E: Downloading ios player API JSON
# [youtube] FL7Vbwtin8E: Downloading mweb player API JSON
# [youtube] FL7Vbwtin8E: Downloading m3u8 information
# [info] FL7Vbwtin8E: Downloading 1 format(s): 251
# [download] Destination: downloads/FL7Vbwtin8E.webm
# [download] 100% of   31.36MiB in 00:00:04 at 6.52MiB/s
# [ExtractAudio] Destination: downloads/FL7Vbwtin8E.mp3
# Deleting original file downloads/gy4Xka9ga4A.webm (pass -k to keep)
# Saved: downloads/gy4Xka9ga4A.mp3
# Deleting original file downloads/IfD_cskfokg.webm (pass -k to keep)
# Saved: downloads/IfD_cskfokg.mp3
# Uploaded to S3: s3://yt-dl-mp3/gy4Xka9ga4A.mp3
# Checking for duplicates: nEJTituDL8A
# Downloading: https://www.youtube.com/watch?v=nEJTituDL8A
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nEJTituDL8A
# [youtube] nEJTituDL8A: Downloading webpage
# Uploaded to S3: s3://yt-dl-mp3/IfD_cskfokg.mp3
# Checking for duplicates: Z2q8_9Hh_I4
# [youtube] nEJTituDL8A: Downloading ios player API JSON
# [youtube] nEJTituDL8A: Downloading mweb player API JSON
# Downloading: https://www.youtube.com/watch?v=Z2q8_9Hh_I4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Z2q8_9Hh_I4
# [youtube] Z2q8_9Hh_I4: Downloading webpage
# [youtube] Z2q8_9Hh_I4: Downloading ios player API JSON
# [youtube] Z2q8_9Hh_I4: Downloading mweb player API JSON
# [youtube] nEJTituDL8A: Downloading m3u8 information
# [info] nEJTituDL8A: Downloading 1 format(s): 251
# [youtube] Z2q8_9Hh_I4: Downloading m3u8 information
# [download] Destination: downloads/nEJTituDL8A.webm
# [download]  49.1% of   36.40MiB at   24.49MiB/s ETA 00:00[info] Z2q8_9Hh_I4: Downloading 1 format(s): 251
# [download]  80.7% of   36.40MiB at   46.32MiB/s ETA 00:00[download] Destination: downloads/Z2q8_9Hh_I4.webm
# [download] 100% of   36.40MiB in 00:00:02 at 16.28MiB/s
# [download]  11.6% of   34.42MiB at    5.49MiB/s ETA 00:05[ExtractAudio] Destination: downloads/nEJTituDL8A.mp3
# [download] 100% of   34.42MiB in 00:00:06 at 5.21MiB/s
# [ExtractAudio] Destination: downloads/Z2q8_9Hh_I4.mp3
# Deleting original file downloads/u5hj3tPlmAs.webm (pass -k to keep)
# Saved: downloads/u5hj3tPlmAs.mp3
# Uploaded to S3: s3://yt-dl-mp3/u5hj3tPlmAs.mp3
# Checking for duplicates: w-wNdzusYuQ
# Downloading: https://www.youtube.com/watch?v=w-wNdzusYuQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=w-wNdzusYuQ
# [youtube] w-wNdzusYuQ: Downloading webpage
# [youtube] w-wNdzusYuQ: Downloading ios player API JSON
# [youtube] w-wNdzusYuQ: Downloading mweb player API JSON
# Deleting original file downloads/FL7Vbwtin8E.webm (pass -k to keep)
# Saved: downloads/FL7Vbwtin8E.mp3
# [youtube] w-wNdzusYuQ: Downloading m3u8 information
# [info] w-wNdzusYuQ: Downloading 1 format(s): 251
# [download] Destination: downloads/w-wNdzusYuQ.webm
# [download]  34.2% of   34.96MiB at    6.24MiB/s ETA 00:03Uploaded to S3: s3://yt-dl-mp3/FL7Vbwtin8E.mp3
# [download]  39.9% of   34.96MiB at    5.41MiB/s ETA 00:03Checking for duplicates: wYHQBv_uAXw
# [download]  68.3% of   34.96MiB at    4.97MiB/s ETA 00:02Downloading: https://www.youtube.com/watch?v=wYHQBv_uAXw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wYHQBv_uAXw
# [youtube] wYHQBv_uAXw: Downloading webpage
# [download]  84.7% of   34.96MiB at    5.24MiB/s ETA 00:01[youtube] wYHQBv_uAXw: Downloading ios player API JSON
# [download]  85.4% of   34.96MiB at    5.12MiB/s ETA 00:00[youtube] wYHQBv_uAXw: Downloading mweb player API JSON
# [download] 100% of   34.96MiB in 00:00:07 at 4.49MiB/s
# [ExtractAudio] Destination: downloads/w-wNdzusYuQ.mp3
# [youtube] wYHQBv_uAXw: Downloading m3u8 information
# [info] wYHQBv_uAXw: Downloading 1 format(s): 251
# [download] Destination: downloads/wYHQBv_uAXw.webm
# [download] 100% of   35.69MiB in 00:00:04 at 8.10MiB/s
# [ExtractAudio] Destination: downloads/wYHQBv_uAXw.mp3
# Deleting original file downloads/Z2q8_9Hh_I4.webm (pass -k to keep)
# Saved: downloads/Z2q8_9Hh_I4.mp3
# Deleting original file downloads/nEJTituDL8A.webm (pass -k to keep)
# Saved: downloads/nEJTituDL8A.mp3
# Uploaded to S3: s3://yt-dl-mp3/Z2q8_9Hh_I4.mp3
# Checking for duplicates: Hterv-4Ccwg
# Downloading: https://www.youtube.com/watch?v=Hterv-4Ccwg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Hterv-4Ccwg
# [youtube] Hterv-4Ccwg: Downloading webpage
# [youtube] Hterv-4Ccwg: Downloading ios player API JSON
# [youtube] Hterv-4Ccwg: Downloading mweb player API JSON
# [youtube] Hterv-4Ccwg: Downloading m3u8 information
# [info] Hterv-4Ccwg: Downloading 1 format(s): 251
# [download] Destination: downloads/Hterv-4Ccwg.webm
# [download]  28.2% of   34.88MiB at    7.94MiB/s ETA 00:03Uploaded to S3: s3://yt-dl-mp3/nEJTituDL8A.mp3
# [download]  28.5% of   34.88MiB at    4.73MiB/s ETA 00:05Checking for duplicates: vDd8CFgXOJs
# [download]  55.6% of   34.88MiB at    5.19MiB/s ETA 00:02Downloading: https://www.youtube.com/watch?v=vDd8CFgXOJs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vDd8CFgXOJs
# [youtube] vDd8CFgXOJs: Downloading webpage
# [download]  61.3% of   34.88MiB at    4.94MiB/s ETA 00:02[youtube] vDd8CFgXOJs: Downloading ios player API JSON
# [download]  67.1% of   34.88MiB at    3.70MiB/s ETA 00:03[youtube] vDd8CFgXOJs: Downloading mweb player API JSON
# [download] 100% of   34.88MiB in 00:00:07 at 4.56MiB/s
# [ExtractAudio] Destination: downloads/Hterv-4Ccwg.mp3
# [youtube] vDd8CFgXOJs: Downloading m3u8 information
# [info] vDd8CFgXOJs: Downloading 1 format(s): 251
# [download] Destination: downloads/vDd8CFgXOJs.webm
# [download]  52.5% of   34.06MiB at    5.51MiB/s ETA 00:02Deleting original file downloads/w-wNdzusYuQ.webm (pass -k to keep)
# Saved: downloads/w-wNdzusYuQ.mp3
# [download] 100% of   34.06MiB in 00:00:09 at 3.74MiB/s
# [ExtractAudio] Destination: downloads/vDd8CFgXOJs.mp3
# Uploaded to S3: s3://yt-dl-mp3/w-wNdzusYuQ.mp3
# Checking for duplicates: qCaSacE_3gU
# Downloading: https://www.youtube.com/watch?v=qCaSacE_3gU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qCaSacE_3gU
# [youtube] qCaSacE_3gU: Downloading webpage
# [youtube] qCaSacE_3gU: Downloading ios player API JSON
# [youtube] qCaSacE_3gU: Downloading mweb player API JSON
# Deleting original file downloads/wYHQBv_uAXw.webm (pass -k to keep)
# Saved: downloads/wYHQBv_uAXw.mp3
# [youtube] qCaSacE_3gU: Downloading m3u8 information
# Uploaded to S3: s3://yt-dl-mp3/wYHQBv_uAXw.mp3
# Checking for duplicates: bzo8mwYhvng
# [info] qCaSacE_3gU: Downloading 1 format(s): 251
# [download] Destination: downloads/qCaSacE_3gU.webm
# [download]  29.5% of   33.85MiB at   10.50MiB/s ETA 00:02Downloading: https://www.youtube.com/watch?v=bzo8mwYhvng
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bzo8mwYhvng
# [youtube] bzo8mwYhvng: Downloading webpage
# [download]  53.1% of   33.85MiB at    8.89MiB/s ETA 00:01[youtube] bzo8mwYhvng: Downloading ios player API JSON
# [download]  58.9% of   33.85MiB at  Unknown B/s ETA Unknown[youtube] bzo8mwYhvng: Downloading mweb player API JSON
# [download] 100% of   33.85MiB in 00:00:04 at 7.58MiB/s
# [ExtractAudio] Destination: downloads/qCaSacE_3gU.mp3
# [youtube] bzo8mwYhvng: Downloading m3u8 information
# [info] bzo8mwYhvng: Downloading 1 format(s): 251
# [download] Destination: downloads/bzo8mwYhvng.webm
# [download] 100% of   37.70MiB in 00:00:03 at 10.78MiB/s
# [ExtractAudio] Destination: downloads/bzo8mwYhvng.mp3
# Deleting original file downloads/Hterv-4Ccwg.webm (pass -k to keep)
# Saved: downloads/Hterv-4Ccwg.mp3
# Uploaded to S3: s3://yt-dl-mp3/Hterv-4Ccwg.mp3
# Checking for duplicates: Ze8oYfZgUUk
# Downloading: https://www.youtube.com/watch?v=Ze8oYfZgUUk
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ze8oYfZgUUk
# [youtube] Ze8oYfZgUUk: Downloading webpage
# [youtube] Ze8oYfZgUUk: Downloading ios player API JSON
# [youtube] Ze8oYfZgUUk: Downloading mweb player API JSON
# Deleting original file downloads/vDd8CFgXOJs.webm (pass -k to keep)
# Saved: downloads/vDd8CFgXOJs.mp3
# [youtube] Ze8oYfZgUUk: Downloading m3u8 information
# [info] Ze8oYfZgUUk: Downloading 1 format(s): 251
# [download] Destination: downloads/Ze8oYfZgUUk.webm
# [download]  28.5% of   40.75MiB at    3.75MiB/s ETA 00:07Uploaded to S3: s3://yt-dl-mp3/vDd8CFgXOJs.mp3
# Checking for duplicates: S-nLfA0_TzA
# [download]  43.2% of   40.75MiB at    4.71MiB/s ETA 00:04Downloading: https://www.youtube.com/watch?v=S-nLfA0_TzA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=S-nLfA0_TzA
# [youtube] S-nLfA0_TzA: Downloading webpage
# [download]  48.8% of   40.75MiB at    7.47MiB/s ETA 00:02[youtube] S-nLfA0_TzA: Downloading ios player API JSON
# [youtube] S-nLfA0_TzA: Downloading mweb player API JSON
# [download]  57.4% of   40.75MiB at    4.17MiB/s ETA 00:04
